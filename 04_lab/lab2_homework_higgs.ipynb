# %% [markdown]
# ### Practical homework: higgs challenge
#
# In this homework, you'll go through all the steps of data analysis from scratch. The dataset for this homework is the famous higgs challenge.
#
# ![img](https://kaggle2.blob.core.windows.net/competitions/kaggle/3887/media/ATLASEXP_image.png)
#
# __Note__: if you participate in the first kaggle competition (PID) and obtain a score above the highest baseline, you don't need to submit this - just send something like "I already got passing score in the PID challenge" or "I am to cool to submit this, mate".

# %% [markdown]
# __Before you begin__ - extract (un-zip) __`./higgs.csv.zip`__ contents to this location. There should be just one file (`higgs.csv`).

# %%
import pandas as pd

data = pd.read_csv("higgs.csv")
X = data.drop("Label",1)
y = data.Label.values

# %%
X[:5]
# Out:
#    DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# 0       138.470                       51.655        97.827    27.980
# 1       160.937                       68.768       103.235    48.146
# 2      -999.000                      162.172       125.953    35.635
# 3       143.905                       81.417        80.943     0.414
# 4       175.864                       16.915       134.805    16.405
#
#    DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 0                  0.91           124.711                2.666
# 1               -999.00          -999.000             -999.000
# 2               -999.00          -999.000             -999.000
# 3               -999.00          -999.000             -999.000
# 4               -999.00          -999.000             -999.000
#
#    DER_deltar_tau_lep  DER_pt_tot  DER_sum_pt       ...        PRI_met_phi  \
# 0               3.064      41.928     197.760       ...             -0.277
# ...

# %%
y[:5]
# Out:
# array(['s', 'b', 'b', 'b', 'b'], dtype=object)

# %% [markdown]
# # Your task
#
# Build a full machine learning pipeline that filters data in the large hadron collider.
#
# Data:
#  * X - decay information (angles, mommenta, energy, etc.)
#  * y - reference answers
#   * 's' - this event contains the decay we need. Keep it.
#   * 'b' - this event contains no interesting decays. Delete it.
#   * Note that you may need to convert y to numeric (0 or 1) for some classifiers to work.
#
#  * Note that data contains NaNs, encoded as -999.0
#
#
# Steps
# * Preprocess data, split into training / validation / test
# * Train machine learning models
#  * try at least one linear model and at least one tree-based model / ensemble
#  * Measure accuracy - ```from sklearn.metrics import accuracy_score```
#  * ... and roc-AUC  - ```from sklearn.metrics import roc_auc_score, roc_curve```
#
# * Select a model that gets best AUC (at least 90%, higher = better)
# * It is legal to use any library and any trick you know, just don't violate common sense (e.g. training on test set).
# * __submit a notebook that:__
#  * can be run from top to bottom (kernel -> Run All works)
#  * spits out some estimate of your model performance (accuracy/auc) on test set.

# %%
< This notebook is yours to modify however you wish >
